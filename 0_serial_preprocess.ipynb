# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
hsource_csv = r"/mnt/c/Users/natha/code/ParallelPython/data/yellow_tripdata_2015-01.csv"

taxi = pd.read_csv(source_csv)

taxi.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
# Data Cleaning
cleaned_taxi = taxi[(taxi['passenger_count'] != 0) & 
                    (taxi['trip_distance'] != 0) &
                    (taxi['fare_amount'] >= 0) &
                    (taxi['total_amount'] >= 0)]

# %%
print(len(taxi))
print(len(cleaned_taxi))
# Out:
# 12748986
# 12660336

# %%
# Convert datetime columns to datetime type
cleaned_taxi['tpep_pickup_datetime'] = pd.to_datetime(cleaned_taxi['tpep_pickup_datetime'])
cleaned_taxi['tpep_dropoff_datetime'] = pd.to_datetime(cleaned_taxi['tpep_dropoff_datetime'])

# %%
# Calculate trip duration in minutes
cleaned_taxi['trip_duration'] = (cleaned_taxi['tpep_dropoff_datetime'] - cleaned_taxi['tpep_pickup_datetime'])

# %%
cleaned_taxi.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...
